# %% [markdown]
# # Importing necessary Libraries

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense,Activation,Dropout,Conv2D,Flatten,MaxPool2D,Reshape,InputLayer
from tensorflow.keras.applications.resnet50 import ResNet50
from tensorflow.keras.applications.resnet50 import preprocess_input
from tensorflow.keras.preprocessing import image
from tensorflow.keras.preprocessing.image import ImageDataGenerator,load_img,img_to_array
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau

# %% [markdown]
# # Data Augumentation
#
# * Dataset consist of 5 classes.
# * **Daisy** - European Species of Aster family.
# * **Sunflower** - Identified as the genus of Helianthus.
# * **Tulip** - Belong to the species of spring blooming geophytes.
# * **Rose** - Belongs to the family of rosaceae.
# * **Dandelion** - Indentifies as the genus of Asterceae.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
path = '/content/drive/MyDrive/IBM/Flowers'

# %%
train_data_gen = ImageDataGenerator(rescale = 1./255,
                             shear_range = 0.2,
                             zoom_range = 0.2,
                             horizontal_flip = True,
                             validation_split = 0.30)
test_data_gen = ImageDataGenerator(rescale = 1./255,validation_split = 0.30)

# %%
training_set = train_data_gen.flow_from_directory(path,
                                                 target_size=(64,64),
                                                 batch_size=100,
                                                 class_mode='categorical',
                                                 shuffle=True,
                                                 color_mode='rgb',
                                                 subset = 'training')

testing_set = test_data_gen.flow_from_directory(path,
                                                 target_size=(64,64),
                                                 batch_size=100,
                                                 class_mode='categorical',
                                                 shuffle=True,
                                                 color_mode='rgb',
                                                 subset = 'validation')
# Out:
# Found 3024 images belonging to 5 classes.
# Found 1293 images belonging to 5 classes.

# %% [markdown]
# # Model building using CNN
# **1. Create the model**

# %%
model = Sequential()

#convolution and Pooling layer 1
model.add(Conv2D(filters=48,kernel_size=3,activation='relu',input_shape=(64,64,3)))
model.add(MaxPool2D(pool_size=2,strides=2))
model.add(Dropout(0.2))

#convolution and Pooling layer 2
model.add(Conv2D(filters=32,kernel_size=3,activation='relu'))
model.add(MaxPool2D(pool_size=2,strides=2))
model.add(Dropout(0.2))

#Flattening the images
model.add(Flatten())

#Fully Connected layers
model.add(Dense(64,activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(5,activation='softmax'))

# %%
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_4 (Conv2D)           (None, 62, 62, 48)        1344
#
#  max_pooling2d_4 (MaxPooling  (None, 31, 31, 48)       0
#  2D)
#
#  dropout_6 (Dropout)         (None, 31, 31, 48)        0
#
#  conv2d_5 (Conv2D)           (None, 29, 29, 32)        13856
#
#  max_pooling2d_5 (MaxPooling  (None, 14, 14, 32)       0
#  2D)
#
#  dropout_7 (Dropout)         (None, 14, 14, 32)        0
#
#  flatten_2 (Flatten)         (None, 6272)              0
#
#  dense_4 (Dense)             (None, 64)                401472
#
#  dropout_8 (Dropout)         (None, 64)                0
#
#  dense_5 (Dense)             (None, 5)                 325
#
# =================================================================
# Total params: 416,997
# Trainable params: 416,997
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# **2. Compile the Model**

# %%
model.compile(loss='categorical_crossentropy',optimizer='adam',metrics=['accuracy'])

# %% [markdown]
# **3. Adding callbacks to avoid overfitting**

# %%
early_stop = EarlyStopping(monitor='val_accuracy', 
                           patience=5,verbose=1,mode='auto')

lr = ReduceLROnPlateau(monitor='val_accuracy', 
                       factor=0.2,patience=5, 
                       min_lr=0.00001)

callback = [early_stop,lr]

# %% [markdown]
# **4. Training the Model**

# %%
result = model.fit(x=training_set, validation_data=testing_set, epochs=50)
# Out:
# Epoch 1/50
# 31/31 [==============================] - 34s 1s/step - loss: 1.4530 - accuracy: 0.3356 - val_loss: 1.2834 - val_accuracy: 0.4346
# Epoch 2/50
# 31/31 [==============================] - 34s 1s/step - loss: 1.2313 - accuracy: 0.4778 - val_loss: 1.2067 - val_accuracy: 0.4888
# Epoch 3/50
# 31/31 [==============================] - 32s 1s/step - loss: 1.1542 - accuracy: 0.5205 - val_loss: 1.1497 - val_accuracy: 0.5298
# Epoch 4/50
# 31/31 [==============================] - 32s 1s/step - loss: 1.0865 - accuracy: 0.5562 - val_loss: 1.1172 - val_accuracy: 0.5383
# Epoch 5/50
# 31/31 [==============================] - 34s 1s/step - loss: 1.0444 - accuracy: 0.5837 - val_loss: 1.0959 - val_accuracy: 0.5630
# Epoch 6/50
# 31/31 [==============================] - 32s 1s/step - loss: 1.0181 - accuracy: 0.5995 - val_loss: 1.0392 - val_accuracy: 0.5940
# Epoch 7/50
# 31/31 [==============================] - 32s 1s/step - loss: 0.9764 - accuracy: 0.6114 - val_loss: 1.0642 - val_accuracy: 0.5901
# Epoch 8/50
# 31/31 [==============================] - 32s 1s/step - loss: 0.9557 - accuracy: 0.6303 - val_loss: 1.0610 - val_accuracy: 0.5947
# Epoch 9/50
# 31/31 [==============================] - 32s 1s/step - loss: 0.9269 - accuracy: 0.6369 - val_loss: 1.0265 - val_accuracy: 0.6040
# Epoch 10/50
# 31/31 [==============================] - 31s 987ms/step - loss: 0.9173 - accuracy: 0.6310 - val_loss: 1.0519 - val_accuracy: 0.6025
# Epoch 11/50
# 31/31 [==============================] - 31s 1s/step - loss: 0.8925 - accuracy: 0.6481 - val_loss: 1.0438 - val_accuracy: 0.6056
# Epoch 12/50
# 31/31 [==============================] - 32s 1s/step - loss: 0.8792 - accuracy: 0.6488 - val_loss: 0.9833 - val_accuracy: 0.6319
# Epoch 13/50
# 31/31 [==============================] - 31s 1s/step - loss: 0.8536 - accuracy: 0.6627 - val_loss: 0.9977 - val_accuracy: 0.6210
# Epoch 14/50
# 31/31 [==============================] - 32s 1s/step - loss: 0.8549 - accuracy: 0.6624 - val_loss: 1.0423 - val_accuracy: 0.6102
# Epoch 15/50
# 31/31 [==============================] - 31s 1s/step - loss: 0.8018 - accuracy: 0.6858 - val_loss: 0.9490 - val_accuracy: 0.6450
# Epoch 16/50
# 31/31 [==============================] - 32s 1s/step - loss: 0.8096 - accuracy: 0.6842 - val_loss: 0.9234 - val_accuracy: 0.6381
# Epoch 17/50
# 31/31 [==============================] - 31s 1s/step - loss: 0.7890 - accuracy: 0.6971 - val_loss: 0.9241 - val_accuracy: 0.6357
# Epoch 18/50
# 31/31 [==============================] - 31s 984ms/step - loss: 0.7704 - accuracy: 0.6978 - val_loss: 0.9077 - val_accuracy: 0.6527
# Epoch 19/50
# 31/31 [==============================] - 32s 1s/step - loss: 0.7686 - accuracy: 0.7083 - val_loss: 0.9640 - val_accuracy: 0.6350
# Epoch 20/50
# 31/31 [==============================] - 31s 1s/step - loss: 0.7413 - accuracy: 0.7123 - val_loss: 0.9767 - val_accuracy: 0.6334
# Epoch 21/50
# 31/31 [==============================] - 31s 998ms/step - loss: 0.7190 - accuracy: 0.7232 - val_loss: 0.9563 - val_accuracy: 0.6396
# Epoch 22/50
# 31/31 [==============================] - 32s 1s/step - loss: 0.7050 - accuracy: 0.7259 - val_loss: 0.9124 - val_accuracy: 0.6698
# Epoch 23/50
# 31/31 [==============================] - 31s 1s/step - loss: 0.6994 - accuracy: 0.7272 - val_loss: 0.8942 - val_accuracy: 0.6674
# Epoch 24/50
# 31/31 [==============================] - 32s 1s/step - loss: 0.6877 - accuracy: 0.7384 - val_loss: 0.9085 - val_accuracy: 0.6558
# Epoch 25/50
# 31/31 [==============================] - 33s 1s/step - loss: 0.6847 - accuracy: 0.7391 - val_loss: 0.9136 - val_accuracy: 0.6605
# Epoch 26/50
# 31/31 [==============================] - 33s 1s/step - loss: 0.6616 - accuracy: 0.7437 - val_loss: 0.9168 - val_accuracy: 0.6783
# Epoch 27/50
# 31/31 [==============================] - 34s 1s/step - loss: 0.6466 - accuracy: 0.7530 - val_loss: 1.0172 - val_accuracy: 0.6411
# Epoch 28/50
# 31/31 [==============================] - 33s 1s/step - loss: 0.6217 - accuracy: 0.7583 - val_loss: 0.9254 - val_accuracy: 0.6628
# Epoch 29/50
# 31/31 [==============================] - 32s 1s/step - loss: 0.6072 - accuracy: 0.7662 - val_loss: 0.9026 - val_accuracy: 0.6690
# Epoch 30/50
# 31/31 [==============================] - 33s 1s/step - loss: 0.6315 - accuracy: 0.7586 - val_loss: 0.9833 - val_accuracy: 0.6713
# Epoch 31/50
# 31/31 [==============================] - 32s 1s/step - loss: 0.6110 - accuracy: 0.7662 - val_loss: 0.8846 - val_accuracy: 0.6883
# Epoch 32/50
# 31/31 [==============================] - 31s 985ms/step - loss: 0.5897 - accuracy: 0.7801 - val_loss: 0.9729 - val_accuracy: 0.6574
# Epoch 33/50
# 31/31 [==============================] - 31s 1s/step - loss: 0.5903 - accuracy: 0.7771 - val_loss: 0.9615 - val_accuracy: 0.6613
# Epoch 34/50
# 31/31 [==============================] - 31s 1s/step - loss: 0.5668 - accuracy: 0.7791 - val_loss: 0.8997 - val_accuracy: 0.6775
# Epoch 35/50
# 31/31 [==============================] - 31s 1s/step - loss: 0.5636 - accuracy: 0.7851 - val_loss: 0.9166 - val_accuracy: 0.6806
# Epoch 36/50
# 31/31 [==============================] - 32s 1s/step - loss: 0.5488 - accuracy: 0.7927 - val_loss: 0.8725 - val_accuracy: 0.6845
# Epoch 37/50
# 31/31 [==============================] - 32s 1s/step - loss: 0.5613 - accuracy: 0.7834 - val_loss: 1.0162 - val_accuracy: 0.6489
# Epoch 38/50
# 31/31 [==============================] - 31s 1s/step - loss: 0.5567 - accuracy: 0.7910 - val_loss: 0.9918 - val_accuracy: 0.6744
# Epoch 39/50
# 31/31 [==============================] - 31s 991ms/step - loss: 0.5416 - accuracy: 0.7847 - val_loss: 0.9158 - val_accuracy: 0.6628
# Epoch 40/50
# 31/31 [==============================] - 31s 1s/step - loss: 0.4982 - accuracy: 0.8161 - val_loss: 0.9069 - val_accuracy: 0.6883
# Epoch 41/50
# 31/31 [==============================] - 31s 998ms/step - loss: 0.5083 - accuracy: 0.8032 - val_loss: 0.9642 - val_accuracy: 0.6752
# Epoch 42/50
# 31/31 [==============================] - 32s 1s/step - loss: 0.4987 - accuracy: 0.8112 - val_loss: 0.9841 - val_accuracy: 0.6419
# Epoch 43/50
# 31/31 [==============================] - 32s 1s/step - loss: 0.5154 - accuracy: 0.8029 - val_loss: 0.9992 - val_accuracy: 0.6674
# Epoch 44/50
# 31/31 [==============================] - 32s 1s/step - loss: 0.4895 - accuracy: 0.8085 - val_loss: 0.9529 - val_accuracy: 0.6605
# Epoch 45/50
# 31/31 [==============================] - 32s 1s/step - loss: 0.4711 - accuracy: 0.8237 - val_loss: 0.9797 - val_accuracy: 0.6790
# Epoch 46/50
# 31/31 [==============================] - 31s 1s/step - loss: 0.4805 - accuracy: 0.8145 - val_loss: 1.0139 - val_accuracy: 0.6535
# Epoch 47/50
# 31/31 [==============================] - 31s 1s/step - loss: 0.4657 - accuracy: 0.8135 - val_loss: 1.0568 - val_accuracy: 0.6721
# Epoch 48/50
# 31/31 [==============================] - 33s 1s/step - loss: 0.4530 - accuracy: 0.8254 - val_loss: 0.9785 - val_accuracy: 0.6868
# Epoch 49/50
# 31/31 [==============================] - 31s 997ms/step - loss: 0.4259 - accuracy: 0.8370 - val_loss: 0.9670 - val_accuracy: 0.6883
# Epoch 50/50
# 31/31 [==============================] - 34s 1s/step - loss: 0.4407 - accuracy: 0.8320 - val_loss: 1.0858 - val_accuracy: 0.6582

# %% [markdown]
# **5. Loss and Accuracy check using plot**

# %%
#plot the loss
plt.plot(result.history['loss'], label='train loss')
plt.plot(result.history['val_loss'], label='val loss')
plt.legend()
plt.show()

# plot the accuracy
plt.plot(result.history['accuracy'], label='train acc')
plt.plot(result.history['val_accuracy'], label='val acc')
plt.legend()
plt.show()

# %% [markdown]
# **6. Save the Model**

# %%
model.save('flower.h5')

# %% [markdown]
# # Testing the Model

# %%
training_set.class_indices
# Out:
# {'daisy': 0, 'dandelion': 1, 'rose': 2, 'sunflower': 3, 'tulip': 4}

# %%
classes = ['Daisy','Dandelion','Rose','Sunflower','Tulip'] 
def testing(img):
    img = image.load_img(img,target_size=(64,64)) 
    x = image.img_to_array(img) 
    x = np.expand_dims(x,axis=0) 
    pred = np.argmax(model.predict(x)) 
    return print("Predicted class as:",classes[pred])

def img_show(img):
    img1 = image.load_img(img,target_size=(64,64)) 
    plt.imshow(img1)

# %%
#test1
img_show('/content/drive/MyDrive/IBM/Flowers/daisy/flower1.jpg')
testing('/content/drive/MyDrive/IBM/Flowers/daisy/flower1.jpg')
# Out:
# Predicted class as: Daisy

# %%
#test2
img_show('/content/drive/MyDrive/IBM/Flowers/rose/flower2.jpg')
testing('/content/drive/MyDrive/IBM/Flowers/rose/flower2.jpg')
# Out:
# Predicted class as: Rose

# %%
#test3
img_show('/content/drive/MyDrive/IBM/Flowers/sunflower/flower3.jpg')
testing('/content/drive/MyDrive/IBM/Flowers/sunflower/flower3.jpg')
# Out:
# Predicted class as: Sunflower

# %%
#test4
img_show('/content/drive/MyDrive/IBM/Flowers/tulip/flower4.jpg')
testing('/content/drive/MyDrive/IBM/Flowers/tulip/flower4.jpg')
# Out:
# Predicted class as: Tulip

# %%
#test5
img_show('/content/drive/MyDrive/IBM/Flowers/dandelion/1.jpg')
testing('/content/drive/MyDrive/IBM/Flowers/dandelion/1.jpg')
# Out:
# Predicted class as: Dandelion

# %% [markdown]
# # Conclusion:
# * The dataset has about 4317 images from 5 different classes.
# * Each classes have more than 500 images for training the data.
# * 30% of the data taken for validation.
# * The accuracy of the model is around 80%.
# * The validation accuracy is around 70%.
# * The model is built with 2 layered convolutional network considering 1344 trainable parameters.
# * Testing the model with unknown images gives 95% accuracy.
